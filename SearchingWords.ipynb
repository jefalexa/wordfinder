# %% [markdown]
# <a href="https://colab.research.google.com/github/jefalexa/wordfinder/blob/main/SearchingWords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Using a Dictionary in Python via NLTK
#
# Documentation:  https://www.nltk.org/howto/corpus.html#corpus-reader-objects
#
# Dataset Options:  https://www.nltk.org/nltk_data/

# %%
import nltk
nltk.download('words')
from nltk.corpus import words
import re
import pandas as pd

# %% [markdown]
# ## Find words that contain certain letters

# %% [markdown]
# ### Specify letters to search for

# %%
# Enter the letters that must be included
letters_to_include = 'Et'

# %% [markdown]
# ### Create the search pattern

# %%
# Create the search string with the appropriate beggining
pattern_temp = "^"

# For each letter in the list, create a search string and append it to the pattern
for l in letters_to_include:
    pattern_temp += f"(?=.*{l})"

# Complete the search pattern with the ending string
pattern_temp += ".*$"

# Now we have the following search pattern
print(f'pattern_temp = {pattern_temp}')

# Compile the string pattern_temp into a REGEX pattern that we can match on
pattern01 = re.compile(pattern_temp, re.IGNORECASE)
print(f'pattern01 = {pattern01}')
# Out:
# pattern_temp = ^(?=.*E)(?=.*t).*$
# pattern01 = re.compile('^(?=.*E)(?=.*t).*$', re.IGNORECASE)

# %% [markdown]
# ### Challenge 1:  Create a function to generate the search pattern
# It should take in a string containing the list of letters to search, and return a REGEX pattern.  Use the template below and fill in the code from the cell above.

# %%
def generate_pattern(letters_to_include):
  # Code here
  return(pattern01)

# %% [markdown]
# ### Test the pattern matching

# %%
w = 'test'
if bool(re.match(pattern01, w)):
    print(w)
# Out:
# test

# %% [markdown]
# ### Search through the words corpus

# %%
matched_words = []

# For each word in nltk.corpus.reader.wordlist.WordListCorpusReader
for w in words.words():
    # If the word matches our pattern, add it to the list
    if bool(re.match(pattern01, w)):
        matched_words.append(w)

print(f"The letters [{letters_to_include}] matched {len(matched_words)} words")
print(matched_words)
# Out:
# The letters [Et] matched 84725 words

# %% [markdown]
# ### Challenge 2:  Create a function to search through the Words Corpus
# It should take a REGEX pattern created by the previous function as input and return a list of matched words.

# %%
def search_words(pattern01):
  # Code here
  return(matched_words)

# %% [markdown]
# ### Challenge 3:  Putting it all together
# Combine the two functions you created to work as a system, then build ontop of that.

# %%
letters_to_include = 'Et'

pattern01 = generate_pattern(letters_to_include)

matched_words = search_words(pattern01)

print(f"The letters [{letters_to_include}] matched {len(matched_words)} words")
print(matched_words)
# Out:
# The letters [Et] matched 84725 words
# ['Aaronite', 'abacate', 'abacinate', 'Abadite', 'abalienate', 'abalienation', 'abandonment', 'Abantes', 'abasement', 'abashment', 'abastardize', 'abatable', 'abate', 'abatement', 'abater', 'abatised', 'abature', 'abbeystede', 'abbreviate', 'abbreviately', 'abbreviation', 'abbreviator', 'abbreviatory', 'abbreviature', 'Abderite', 'abdest', 'abdicate', 'abdicative', 'abditive', 'abdominoanterior', 'abdominocentesis', 'abdominogenital', 'abdominohysterectomy', 'abdominohysterotomy', 'abdominoposterior', 'abducent', 'Abelite', 'abelite', 'abeltree', 'abenteric', 'abepithymia', 'aberrant', 'aberrate', 'aberration', 'aberrational', 'aberrator', 'aberrometer', 'aberuncator', 'abet', 'abetment', 'abettal', 'abettor', 'abevacuation', 'abeyant', 'abhorrent', 'abhorrently', 'abietate', 'abietene', 'abietic', '
# %% [markdown]
# ----------
# # Example:
# ## Sort words into lists depending on patterns matched

# %%
# Create regex filters for different types of words
pattern01 = re.compile(".*ie.*", re.IGNORECASE)
pattern02 = re.compile(".*ei.*", re.IGNORECASE)

# Create empty lists to hold the words that match
pattern01_words = []
pattern02_words = []

# Iterate through the corpus looking for words that match one of the filters
for w in words.words():
    w = w.lower()
    if bool(re.match(pattern01, w)):
        pattern01_words.append(w)
    elif bool(re.match(pattern02, w)):
        pattern02_words.append(w)

print("Done!")
# Out:
# Done!

# %%
print(f'pattern01 = {pattern01}')
print('Matching words:')
print(pattern01_words)
# Out:
# pattern01 = re.compile('.*ie.*', re.IGNORECASE)
# Matching words:
# ['abalienate', 'abalienation', 'abbie', 'abdiel', 'abie', 'abies', 'abietate', 'abietene', 'abietic', 'abietin', 'abietineae', 'abietineous', 'abietinic', 'abiezer', 'abortient', 'abortifacient', 'absorbefacient', 'abthainrie', 'acadie', 'accidie', 'accipient', 'accompanier', 'acetifier', 'acetothienone', 'achievable', 'achieve', 'achievement', 'achiever', 'achromobacterieae', 'acidifier', 'acier', 'acierage', 'acieral', 'acierate', 'acieration', 'acquiesce', 'acquiescement', 'acquiescence', 'acquiescency', 'acquiescent', 'acquiescently', 'acquiescer', 'acquiescingly', 'acrasieae', 'actifier', 'actinodielectric', 'acturience', 'adagietto', 'addie', 'adiel', 'adieu', 'adieux', 'adoulie', 'adrienne', 'advenience', 'advenient', 'aeolsklavier', 'aerie', 'aeried', 'afield', 'afterfriend', 'aftergrief', 'afterpiece', 'aggie', 'aggrievance', 'aggrieve', 'aggrieved', 'aggrievedly', 'aggrievedness', 'aggrievement', 'agiel', 'agonied', 'agyieus', 'aiel', 'ailie', 'airfield', 'airified', 'aitchpiece', 'algefacient', 'algieba', 'alien', 'alienability', 'alienable', 'alienage', 'alienate', 'alienation', 'alienator', 'aliency', 'alienee', 'aliener', 'alienicola', 'alienigenate', 'alienism', 'alienist', 'alienize', 'alienor', 'alienship', 'aliethmoid', 'aliethmoidal', 'alimonied', 'alisier', 'alliciency', 'allicient', 'allie', 'allied', 'allies', 'allies', 'almadie', 'alpieu', 'alquier', 'altarpiece', 'ambience', 'ambiency', 'ambiens', 'ambient', 'ambier', 'amelanchier', 'ammoniemia', 'ammonifier', 'amoebobacterieae', 'amphibiety', 'amphierotic', 'amphierotism', 'amplifier', 'anaerobies', 'anchietea', 'anchietin', 'anchietine', 'anchieutectic', 'ancience', 'anciency', 'ancient', 'ancientism', 'anciently', 'ancientness', 'ancientry', 'ancienty', 'andries', 'angie', 'angiectasis', 'angiectopia', 'angiemphraxis', 'angiopoietic', 'aniellidae', 'aniente', 'animalier', 'ankylopoietic', 'annie', 'anniellidae', 'ansarie', 'anteroparietal', 'antevenient', 'antialien', 'antiantienzyme', 'anticonscience', 'anticourtier', 'antiecclesiastic', 'antiecclesiastical', 'antiedemic', 'antieducation', 'antieducational', 'antiegotism', 'antiejaculation', 'antiemetic', 'antiemperor', 'antiempirical', 'antiendotoxin', 'antiendowment', 'antienergistic', 'antienthusiastic', 'antienzyme', 'antienzymic', 'antiepicenter', 'antiepileptic', 'antiepiscopal', 'antiepiscopist', 'antiepithelial', 'antierosion', 'antierysipelas', 'antietam', 'antiethnic', 'antieugenic', 'antievangelical', 'antievolution', 'antievolutionist', 'antiexpansionist', 'antiexporting', 'antiextreme', 'antieyestrain', 'antihierarchical', 'antihierarchist', 'antihygienic', 'antimedieval', 'antipriest', 'antipriestcraft', 'antirabies', 'antiscientific', 'anukabiet', 'anxietude', 'anxiety', 'aperient', 'apiece', 'apieces', 'apostrophied', 'appercipient', 'applied', 'appliedly', 'applier', 'arabesquerie', 'aralie', 'arbalestrier', 'archchief', 'archfiend', 'archfriend', 'archie', 'archiepiscopacy', 'archiepiscopal', 'archiepiscopally', 'archiepiscopate', 'archiereus', 'archpiece', 'archpriest', 'archpriesthood', 'archpriestship', 'archthief', 'argufier', 'ariegite', 'ariel', 'ariel', 'arienzo', 'aries', 'arietation', 'arietid', 'arietinous', 'arietta', 'armied', 'armoried', 'armpiece', 'arrie', 'arriere', 'arriet', 'arteriectasia', 'arteriectasis', 'arteriectopia', 'artie', 'asclepieion', 'asiento', 'asphyxied', 'asplenieae', 'assentient', 'assientist', 'assiento', 'assoilzie', 'astonied', 'astrier', 'atelier', 'atrienses', 'atriensis', 'atrophied', 'aubrietia', 'aubrietia', 'audience', 'audiencier', 'audient', 'aumrie', 'auntie', 'auriculoparietal', 'aussie', 'autoscience', 'awearied', 'aziethane', 'azofier', 'azotobacterieae', 'babbie', 'babied', 'babyfied', 'bacillarieae', 'backfield', 'backfriend', 'backie', 'backiebird', 'backpiece', 'backspier', 'backspierer', 'bacteriemia', 'baggie', 'baiera', 'baikie', 'bailie', 'bailiery', 'bailieship', 'bailpiece', 'bainie', 'bairnie', 'bakie', 'balbutient', 'ba ...

# %%
print(f'pattern02 = {pattern02}')
print('Matching words:')
print(pattern02_words)
# Out:
# pattern02 = re.compile('.*ei.*', re.IGNORECASE)
# Matching words:
# ['abeigh', 'absenteeism', 'acanthodei', 'acetylenediurein', 'acetyltropeine', 'acheilia', 'acheilous', 'acheiria', 'acheirous', 'acheirus', 'achilleid', 'achilleine', 'acipenseroidei', 'acleidian', 'acleistous', 'acmaeidae', 'acneiform', 'acraein', 'acraeinae', 'acrolein', 'acropoleis', 'aculeiform', 'adeleidae', 'adigei', 'affeir', 'affreight', 'affreighter', 'affreightment', 'agreeing', 'agreeingly', 'airfreight', 'airfreighter', 'aischrolatreia', 'akenobeite', 'albeit', 'alethopteis', 'alexandreid', 'allocaffeine', 'allogeneity', 'allotheism', 'alloxyproteic', 'almeidina', 'alnein', 'alqueire', 'alsweill', 'althaein', 'althein', 'altheine', 'ambrein', 'ameiuridae', 'ameiurus', 'ameiva', 'amenorrheic', 'amidocaffeine', 'amioidei', 'ampangabeite', 'amueixa', 'anapeiratic', 'anapneic', 'anapnoeic', 'anapodeictic', 'anaseismic', 'androgyneity', 'animotheism', 'aniseikonia', 'aniseikonic', 'ankylocheilia', 'anseis', 'anteinitial', 'antheia', 'anthropomorphotheist', 'anthropotheism', 'antiatheism', 'antiatheist', 'antifideism', 'antiforeign', 'antiforeignism', 'antigonorrheic', 'antihemorrheidal', 'antimallein', 'antipleion', 'antiseismic', 'antitheism', 'antitheist', 'antitheistic', 'antitheistical', 'antitheistically', 'antiturnpikeism', 'apartheid', 'apeiron', 'apneic', 'apocaffeine', 'apocodeine', 'apodeipnon', 'apodeixis', 'apogaeic', 'apogeic', 'apperceive', 'araneid', 'araneida', 'araneidan', 'araneiform', 'araneiformes', 'araneiformia', 'aranein', 'araneina', 'archdeceiver', 'archeion', 'archicleistogamous', 'archicleistogamy', 'ardeidae', 'areito', 'argentoproteinum', 'aroeira', 'arseniopleite', 'arthrocleisis', 'arthrosteitis', 'aseismatic', 'aseismic', 'aseismicity', 'aseity', 'aselgeia', 'aspidoganoidei', 'asteism', 'astraeid', 'astraeidae', 'astraeiform', 'atheism', 'atheist', 'atheistic', 'atheistical', 'atheistically', 'atheisticalness', 'atheize', 'atheizer', 'aureity', 'autoreinfusion', 'autotheism', 'autotheist', 'aweigh', 'azogallein', 'azoprotein', 'baccheion', 'bacterioprotein', 'bakalei', 'balei', 'baleise', 'baltei', 'bantamweight', 'barbeiro', 'bathyseism', 'batoidei', 'beadleism', 'beeish', 'beeishness', 'befreight', 'beice', 'beid', 'beige', 'being', 'beingless', 'beingness', 'beinked', 'beira', 'beisa', 'beloeilite', 'beneighbored', 'benzein', 'berkeleian', 'berkeleianism', 'berycoidei', 'beveil', 'bindheimite', 'bisbeeite', 'bitheism', 'blueing', 'bobsleigh', 'bodleian', 'boleite', 'boodleism', 'boodleize', 'boreiad', 'boreism', 'botein', 'brachioganoidei', 'brachysclereid', 'bracteiform', 'bradyseism', 'bradyseismal', 'bradyseismic', 'bradyseismical', 'bradyseismism', 'brazilein', 'breastheight', 'brei', 'breislakite', 'breithauptite', 'bretschneideraceae', 'bromeigon', 'bromeikon', 'bromeikon', 'bromoprotein', 'buddleia', 'butein', 'byegaein', 'cabureiba', 'cadiueio', 'caffeic', 'caffeina', 'caffeine', 'caffeinic', 'caffeinism', 'caffeism', 'calceiform', 'callisteia', 'cameist', 'campodeid', 'campodeidae', 'campodeiform', 'canoeing', 'canoeiro', 'canoeist', 'carlyleian', 'cartilaginei', 'caseic', 'casein', 'caseinate', 'caseinogen', 'cassiopeia', 'cassiopeian', 'cassiopeid', 'cassiopeium', 'catapleiite', 'catchweight', 'ceiba', 'ceibo', 'ceil', 'ceile', 'ceiler', 'ceilidh', 'ceiling', 'ceilinged', 'ceilingward', 'ceilingwards', 'ceilometer', 'cepheid', 'cerasein', 'cerulein', 'ceruleite', 'chaldaei', 'charicleia', 'chausseemeile', 'checkrein', 'checkweigher', 'cheilanthes', 'cheilitis', 'cheilodipteridae', 'cheilodipterus', 'cheilostomata', 'cheilostomatous', 'cheir', 'cheiragra', 'cheiranthus', 'cheirogaleus', 'cheiroglossa', 'cheirognomy', 'cheirography', 'cheirolin', 'cheirology', 'cheiromancy', 'cheiromegaly', 'cheiropatagium', 'cheiropodist', 'cheiropody', 'cheiropompholyx', 'cheiroptera', 'cheiropterygium', 'cheirosophy', 'cheirospasm', 'cheirotherium', 'chimaeroidei', 'choleic', 'choleine', 'choleinic', 'cholophein', 'chondroganoidei', 'chondroprotein', 'chondrostei', 'chordeiles', 'choreic',  ...
